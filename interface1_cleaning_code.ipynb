# %%
from google.colab import drive
from google.colab import files
import pandas as pd
import altair as alt

# %%
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
chronic_disease_df = pd.read_csv("/content/drive/MyDrive/BMI706 Project/U.S._Chronic_Disease_Indicators__CDI_.csv", low_memory = False)

# %%
chronic_disease_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc DataSource   Topic  \
# 0       2014     2014           AR              Arkansas  SEDD; SID  Asthma
# 1       2018     2018           CO              Colorado  SEDD; SID  Asthma
# 2       2018     2018           DC  District of Columbia  SEDD; SID  Asthma
# 3       2017     2017           GA               Georgia  SEDD; SID  Asthma
# 4       2010     2010           MI              Michigan  SEDD; SID  Asthma
#
#                       Question  Response DataValueUnit DataValueType  ...  \
# 0  Hospitalizations for asthma       NaN           NaN        Number  ...
# 1  Hospitalizations for asthma       NaN           NaN        Number  ...
# 2  Hospitalizations for asthma       NaN           NaN        Number  ...
# 3  Hospitalizations for asthma       NaN           NaN        Number  ...
# 4  Hospitalizations for asthma       NaN           NaN        Number  ...
#
# ...

# %%
chronic_disease_df.keys()
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'Topic', 'Question', 'Response', 'DataValueUnit', 'DataValueType',
#        'DataValue', 'DataValueAlt', 'DataValueFootnoteSymbol',
#        'DatavalueFootnote', 'LowConfidenceLimit', 'HighConfidenceLimit',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'StratificationCategory3', 'Stratification3',
#        'GeoLocation', 'ResponseID', 'LocationID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'StratificationCategoryID1', 'StratificationID1',
#        'StratificationCategoryID2', 'StratificationID2',
#        'StratificationCategoryID3', 'StratificationID3'],
#       dtype='object')

# %% [markdown]
# # Data Clean

# %%
chronic_disease_df = chronic_disease_df[chronic_disease_df['StratificationCategoryID1'] == 'OVERALL']
chronic_disease_df = chronic_disease_df[chronic_disease_df['LocationDesc'] != 'United States']

questions = ['Asthma mortality rate',
             'Cancer of the oral cavity and pharynx, mortality',
             'Cancer of the colon and rectum (colorectal), mortality',
             'Cancer of the lung and bronchus, mortality',
             'Cancer of the female cervix, mortality',
             'Melanoma, mortality',
             'Mortality with end-stage renal disease',
             'Mortality from cerebrovascular disease (stroke)',
             'Mortality from coronary heart disease',
             'Chronic liver disease mortality',
             'Obesity among adults aged >= 18 years',
             'Healthy weight among adults aged >= 18 years',
             'Per capita alcohol consumption among persons aged >= 14 years',
             'Current smoking among adults aged >= 18 years']
chronic_disease_df_new = chronic_disease_df.loc[chronic_disease_df['Question'].isin(questions[:10])]
risk_factor_df = chronic_disease_df.loc[chronic_disease_df['Question'].isin(questions[10:])]

chronic_disease_df_new = chronic_disease_df_new.copy()
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Asthma mortality rate', 'Question'] = 'Asthma'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Cancer of the oral cavity and pharynx, mortality', 'Question'] = 'Oral cavity and pharynx cancer'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Cancer of the colon and rectum (colorectal), mortality', 'Question'] = 'Colorectal cancer'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Cancer of the lung and bronchus, mortality', 'Question'] = 'Lung and bronchus cancer'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Cancer of the female cervix, mortality', 'Question'] = 'Female cervix cancer'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Melanoma, mortality', 'Question'] = 'Melanoma'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Mortality with end-stage renal disease', 'Question'] = 'End-stage renal disease'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Mortality from cerebrovascular disease (stroke)', 'Question'] = 'Stroke'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Mortality from coronary heart disease', 'Question'] = 'Coronary heart disease'
chronic_disease_df_new.loc[chronic_disease_df_new.Question == 'Chronic liver disease mortality', 'Question'] = 'Chronic liver disease'
risk_factor_df = risk_factor_df.copy()
risk_factor_df.loc[risk_factor_df.Question == 'Obesity among adults aged >= 18 years', 'Question'] = 'Obesity'
risk_factor_df.loc[risk_factor_df.Question == 'Healthy weight among adults aged >= 18 years', 'Question'] = 'Healthy weight'
risk_factor_df.loc[risk_factor_df.Question == 'Per capita alcohol consumption among persons aged >= 14 years', 'Question'] = 'Per capita alcohol consumption'
risk_factor_df.loc[risk_factor_df.Question == 'Current smoking among adults aged >= 18 years', 'Question'] = 'Smoking'

chronic_disease_df_new = chronic_disease_df_new[chronic_disease_df_new['DataValueType'].isin(['Age-adjusted Rate', 'Average Annual Age-adjusted Rate'])]
chronic_disease_df_new = chronic_disease_df_new.rename(columns={'DataValue': 'Rate'})
risk_factor_df = risk_factor_df[risk_factor_df['DataValueType'].isin(['Age-adjusted Prevalence', 'Per capita alcohol consumption'])]
risk_factor_df = risk_factor_df.rename(columns={'DataValue': 'Amount'})

# %% [markdown]
# # Interface 1. Relationship between Chronic Disease Mortality and Risk Factors

# %%
interface_1_df_1 = chronic_disease_df_new[['YearStart', 'LocationDesc', 'Question', 'Rate', 'LocationID']]
interface_1_df_2 = risk_factor_df[['YearStart', 'LocationDesc', 'Question', 'Amount', 'LocationID']]

# %%
interface_1_df_1.head()
# Out:
#      YearStart          LocationDesc               Question  Rate  LocationID
# 271       2015                Oregon  Chronic liver disease  13.7          41
# 387       2020               Florida  Chronic liver disease  13.0          12
# 479       2016              Maryland  Chronic liver disease   6.7          24
# 480       2013  District of Columbia  Chronic liver disease   8.1          11
# 538       2013              Missouri  Chronic liver disease   8.4          29

# %%
interface_1_df_2.head()
# Out:
#        YearStart LocationDesc                        Question Amount  \
# 16122       2016       Nevada  Per capita alcohol consumption    3.5
# 16150       2014     New York  Per capita alcohol consumption    2.2
# 16198       2019      Arizona  Per capita alcohol consumption    2.2
# 16199       2018  Puerto Rico  Per capita alcohol consumption    NaN
# 16226       2010     Maryland  Per capita alcohol consumption    2.2
#
#        LocationID
# 16122          32
# 16150          36
# 16198           4
# 16199          72
# 16226          24

# %%
interface_1_df_1.to_csv('interface_1_df_1.csv', index = False)
files.download('interface_1_df_1.csv')

# %%
interface_1_df_2.to_csv('interface_1_df_2.csv', index = False)
files.download('interface_1_df_2.csv')
